# %% [markdown]
# ## 104爬蟲
# [104 API](http://www.104.com.tw/i/api_doc/jobsearch/documentation.cfm#this)

# %%
import requests
from bs4 import BeautifulSoup
apiStr = 'http://www.104.com.tw/i/apis/jobsearch.cfm'

# %%
requests.get("http://www.104.com.tw/i/apis/jobsearch.cfm?cat=2007001006&role=1,4&fmt=2")
# Out:
# <Response [200]>

# %%
import json
res = requests.get("http://www.104.com.tw/i/apis/jobsearch.cfm?cat=2007001006&role=1,\
                    4&fmt=8&cols=J,JOB,NAME,PCSKILL_ALL_DESC,JOBSKILL_ALL_DESC")

res.text
# Out:
# '{"RECORDCOUNT":"4482","PAGECOUNT":"20","PAGE":"1","TOTALPAGE":"225","data":[{"J":"444a4424566c49693c423b1d382e365f2383a426b34363e673c423a1d1d1d1d5f24470363189j52","JOB":"ASP.Net C# 工程師","JOBSKILL_ALL_DESC":"","NAME":"冠品資訊服務有限公司","PCSKILL_ALL_DESC":"AJAX C#"},{"J":"5367492d61735070434942243f353d6643f4149723b3d456e434941242424242084c77493816j51","JOB":"APP開發工程師","JOBSKILL_ALL_DESC":"","NAME":"冠品資訊服務有限公司","PCSKILL_ALL_DESC":""},{"J":"47514b2e53735070434942243f353d6643f4149723b3d456e434941242424246644d51493816j55","JOB":"ASP C#.Net MVC資深工程師","JOBSKILL_ALL_DESC":"","NAME":"冠品資訊服務有限公司","PCSKILL_ALL_DESC":""},{"J":"3739436d5d6b482459413b62512d355e13739416a33353d663b41391c1c1c1c619435f393098j55","JOB":"前往日本就職吧！日文軟體開發工程師／JAVA、PHP知識～開發經驗重視〃980","JOBSKILL_ALL_DESC":"","NAME":"echoas  Taiwan_愛司人才管理顧問股份有限公司","PCSKILL_ALL_DESC":"Java PHP"},{"J":"4b49416c5d6b486733413b1d552d355e13739416a33353d663b41391c1c1c1c186445f393098j98","JOB":"軟體工程師","JOBSKILL_ALL_DESC":"","NAME":"科迪股份有限公司","PCSKILL_ALL_DESC":""},{"J":"5f75472b414b455b36373f6845433c1e1674f472b414b4326262626683e402b2a735j02","JOB":"POS系統程式設計師","JOBSKILL_ALL_DESC":"","NAME":"日躍科技股份有限公司","PCSKILL_ALL_DESC":""},{"J":"434d466f616f4c6a55453e233331396203b3d456e3739416a3f453d202020201f2494d5b3452j51","JOB":"iOS APP 軟體 工程師 (台北)【此職務包含想上集團所屬公司】","JOBSKILL_ALL_DESC":"軟體工程系統開發 軟體品質與保證 軟體整合測試 軟體程式設計","NAME":"想上數位廣告股份有限公司","PCSKILL_ALL_DESC":"iOS C++ Objective-C SWIFT"},{"J":"454f487163714e6c5747402535333b6423d3f4770393b436c41473f222222222194b3f4f3634j53","JOB":"Android 軟體 工程師 (台北)【此職務包含想上集團所屬公司】","JOBSKILL_ALL_DESC":"軟體工程系統開發 軟體品質與保證 軟體整合測試 軟體程式設計","NAME":"想上數位廣告股份有限公司","PCSKILL_ALL_DESC":"Android Java"},{"J":"4b6f4228596b486651413a1f2f2d355e13739416a33353d663b41391c1c1c1c6194549393098j98","JOB":"Android 軟體 工程師 (台中)【此職務包含想上集團所屬公司】","JOBSKILL_ALL_DESC":"軟體工程系統開發 軟體品質與保證 軟體整合測試 軟體程式設計","NAME":"想上數位廣告股份有限公司","PCSKILL_ALL_DESC":"Android Java"},{"J":"54784b316274516f5a4a432838363e67540424a733c3e466f444a42252525256a74d52463907j52","JOB":"iOS APP 軟體 工程師 (台中)【此職務包含想上集團所屬公司】","JOBSKILL_ALL_DESC":"軟體工程系統開發 軟體品質與保證 軟體整合測試 軟體程式設計","NAME":"想上數位廣告股份有限公司","PCSKILL_ALL_DESC":"iOS C++ Objective-C SWIFT"},{"J":"534d45295d6f4c6a55453e233331396203b3d456e3739416a3f453d2020202064247635b3452j51","JOB":"系統開發工程師","JOBSKILL_ALL_DESC":"系統整合分析 軟體工程系統開發","NAME":"想上數位廣告股份有限公司","PCSKILL_ALL_DESC":"C# Java PHP Python"},{"J":"6551492b6173506e5949422737353d6643f4149723b3d456e434941242424242194d51493816j53","JOB":"PHP程式工程師 (後端工程師、後台工程師)","JOBSKILL_ALL_DESC":"系統整合分析 軟體工程系統開發","NAME":"想上數位廣告股份有限公司","PCSKILL_ALL_DESC":"AJAX PHP MySQL HTML JavaScript jQuery"},{"J":"4e404a7364724f263a38412542343c6533e4048713a3c446d424840232323232084a764c3725j01","JOB":"資安研發助理工程師","JOBSKILL_ALL_DESC":"","NAME":"安華聯網科技股份有限公司","PCSKILL_ALL_DESC":""},{"J":"503e462a5e704d2438363f2340323a6313c3e466f383a426b40463e212121216424974523543j48","JOB":"資安研發工程師(替代役)","JOBSKILL_ALL_DESC":"","NAME":"安華聯網科技股份有限公司","PCSKILL_ALL_DESC":"C C++ Java Perl Python"},{"J":"613d46294f5f425934353d6633413a6205373467061494224242424683c642928654j49","JOB":"PHP 程式設計師 (新店)","JOBSKILL_ALL_DESC":"","NAME":"健和興端子股份有限公司","PCSKILL_ALL_DESC":"PHP MySQL HTML JavaScript"},{"J":"5e60436c406c3f5631323a63303e375f25070436d5e463f2121212163382b2625381j01","JOB":"網頁前端工程師(新店)","JOBSKILL_ALL_DESC":"","NAME":"健和興端子股份有限公司","PCSKILL_ALL_DESC":"AJAX PHP MySQL HTML JavaScript jQuery"},{"J":"48524b305e74512d5a4a422544363e67540424a733c3e466f444a42252525252204c52463907j56","JOB":"PHP網站工程師","JOBSKILL_ALL_DESC":"","NAME":"潔客幫股份有限公司","PCSKILL_ALL_DESC":"PHP MySQL HTML JavaScript jQuery"},{"J":"434d462c5d6f4c2855453d203f31396203b3d456e3739416a3f453d202020201f2474d5b3452j51","JOB":"資深網站工程師","JOBSKILL_ALL_DESC":"","NAME":"潔客幫股份有限公司","PCSKILL_ALL_DESC":"PHP MySQL HTML JavaScript jQuery"},{"J":"6967492e473d475d3c39416a3f353e697536749735d4d47282828286a3f682d2c917j57","JOB":"網站設計師(PC-T客邦)","JOBSKILL_ALL_DESC":"","NAME":"城邦文化事業股份有限公司","PCSKILL_ALL_DESC":""},{"J":"6a524c754064475e3d3a426b40363f6a754684a745e4e48292929296e405 ...

# %% [markdown]
# ## ver0.9
#
# 來自:https://github.com/CYCEvans/iii

# %%
import json
from collections import Counter
from urllib.request import urlopen
#找出你要的頁面數
def getPageNumber(web):
    html = urlopen(web)
    jsonObj = json.load(html)
    # 得到key為TOTALPAGE的總頁數(字串)
    num = jsonObj.get("TOTALPAGE")
    return num
#讀取資料(頁面數)
def getData(pagenum , weburl):
    result = Counter()
    #迭代所有頁數
    for n in range(1,pagenum+1):
        #api網址:cat職位名稱 page={} PCSKILL_ALL_DESC:電腦技術
        # 2007001000 軟體╱工程類人員全部
        web = weburl.format(n)
        #得到json格式的文字檔
        html = urlopen(web)
        #得到json物件
        jsonObj = json.load(html)
        #得到key為data的list
        lst = jsonObj.get("data")
        for obj in lst:
            #排除list中物件為{}或是電腦技術沒有的物件
            if not (obj == {} or obj['PCSKILL_ALL_DESC'] == ''):
                #電腦技術全部小寫後切片，加入Counter計數
                lstB = obj['PCSKILL_ALL_DESC'].lower().split(" ")
                for objB in lstB:
                    result[objB] +=1
    return result
if __name__ == "__main__":
    #api網址:cat職位名稱 page={} PCSKILL_ALL_DESC:電腦技術
    # 2007001000
    # 2007001000 軟體╱工程類人員全部
    weburl = "http://www.104.com.tw/i/apis/jobsearch.cfm?cat=2007001000&fmt=8&page={}&pgsz=200&cols=PCSKILL_ALL_DESC"
    num = int(getPageNumber(weburl))
    print(num)
    print(getData(num, weburl).most_common(20))
# Out:
# 86
# [('c', 3490), ('c++', 3281), ('java', 1676), ('linux', 1551), ('c#', 1185), ('javascript', 1155), ('visual', 1080), ('html', 975), ('sql', 914), ('ms', 897), ('android', 803), ('mysql', 735), ('jquery', 628), ('excel', 628), ('windows', 623), ('word', 621), ('python', 504), ('asp.net', 472), ('studio', 448), ('ajax', 445)]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
D = getData(num, weburl).most_common(20) #List obj

# %%
labels, values = zip(*D) #equals to labels = [x for x in D[0]] values =  [x for x in D[1]]

indexes = np.arange(len(labels))
width = 0.5

plt.figure(figsize=(18, 18))
plt.bar(indexes,[y//100 for y in values], width)
plt.xticks(indexes , labels)


plt.show()

# %% [markdown]
# ## 下一步?
# 1. 再細分職業分類
# 2. 時間分類
# 3. 綜合以上兩種
